# %% [markdown]
# <a href="https://colab.research.google.com/github/pgs17/Kaggle-Playground-Notebooks/blob/main/S3_E14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle -q

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle competitions download -c playground-series-s3e14
# Out:
# ...
#   0% 0.00/634k [00:00<?, ?B/s]
# 100% 634k/634k [00:00<00:00, 150MB/s]

# %%
# !unzip playground-series-s3e14.zip
# Out:
# Archive:  playground-series-s3e14.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv('/content/train.csv')
test=pd.read_csv('/content/test.csv')
submission=pd.read_csv('/content/sample_submission.csv')

# %%
train.head()
# Out:
#    id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0   0       25.0      0.50     0.25     0.75   0.50              69.7
# 1   1       25.0      0.50     0.25     0.50   0.50              69.7
# 2   2       12.5      0.25     0.25     0.63   0.63              86.0
# 3   3       12.5      0.25     0.25     0.63   0.50              77.4
# 4   4       25.0      0.50     0.25     0.63   0.63              77.4
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              42.1                  58.2              50.2              24.3
# 1              42.1                  58.2              50.2              24.3
# 2              52.0                  71.9              62.0              30.0
# 3              46.8                  64.7              55.8              27.0
# 4              46.8                  64.7              55.8              27.0
#
# ...

# %%
test.head()
# Out:
#       id  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0  15289       25.0      0.25     0.25     0.25   0.25              86.0
# 1  15290       12.5      0.25     0.25     0.75   0.63              94.6
# 2  15291       12.5      0.25     0.25     0.63   0.63              86.0
# 3  15292       25.0      0.50     0.38     0.38   0.63              86.0
# 4  15293       37.5      0.75     0.25     0.25   0.25              94.6
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              57.2                  79.0              68.2              33.0
# 2              52.0                  71.9              62.0              30.0
# 3              52.0                  71.9              62.0              30.0
# 4              57.2                  79.0              68.2              33.0
#
# ...

# %%
submission.head(3)
# Out:
#       id     yield
# 0  15289  6025.194
# 1  15290  6025.194
# 2  15291  6025.194

# %%
train.describe()
# Out:
#                  id     clonesize      honeybee       bumbles       andrena  \
# count  15289.000000  15289.000000  15289.000000  15289.000000  15289.000000
# mean    7644.000000     19.704690      0.389314      0.286768      0.492675
# std     4413.698468      6.595211      0.361643      0.059917      0.148115
# min        0.000000     10.000000      0.000000      0.000000      0.000000
# 25%     3822.000000     12.500000      0.250000      0.250000      0.380000
# 50%     7644.000000     25.000000      0.500000      0.250000      0.500000
# 75%    11466.000000     25.000000      0.500000      0.380000      0.630000
# max    15288.000000     40.000000     18.430000      0.585000      0.750000
#
#               osmia  MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# count  15289.000000      15289.000000      15289.000000          15289.000000
# mean       0.592355         82.169887         49.673281             68.656256
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15289 entries, 0 to 15288
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15289 non-null  int64
#  1   clonesize             15289 non-null  float64
#  2   honeybee              15289 non-null  float64
#  3   bumbles               15289 non-null  float64
#  4   andrena               15289 non-null  float64
#  5   osmia                 15289 non-null  float64
#  6   MaxOfUpperTRange      15289 non-null  float64
#  7   MinOfUpperTRange      15289 non-null  float64
#  8   AverageOfUpperTRange  15289 non-null  float64
#  9   MaxOfLowerTRange      15289 non-null  float64
#  10  MinOfLowerTRange      15289 non-null  float64
#  11  AverageOfLowerTRange  15289 non-null  float64
#  12  RainingDays           15289 non-null  float64
#  13  AverageRainingDays    15289 non-null  float64
# ...

# %%
train.isnull().sum()
# Out:
# id                      0
# clonesize               0
# honeybee                0
# bumbles                 0
# andrena                 0
# osmia                   0
# MaxOfUpperTRange        0
# MinOfUpperTRange        0
# AverageOfUpperTRange    0
# MaxOfLowerTRange        0
# MinOfLowerTRange        0
# AverageOfLowerTRange    0
# RainingDays             0
# AverageRainingDays      0
# fruitset                0
# fruitmass               0
# seeds                   0
# yield                   0
# dtype: int64

# %%
test.describe()
# Out:
#                  id     clonesize      honeybee       bumbles       andrena  \
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean   20385.500000     19.795958      0.391606      0.286307      0.491328
# std     2942.898656      6.591864      0.390022      0.059867      0.148166
# min    15289.000000     10.000000      0.000000      0.000000      0.000000
# 25%    17837.250000     12.500000      0.250000      0.250000      0.380000
# 50%    20385.500000     25.000000      0.500000      0.250000      0.500000
# 75%    22933.750000     25.000000      0.500000      0.380000      0.630000
# max    25482.000000     37.500000     18.430000      0.585000      0.750000
#
#               osmia  MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# count  10194.000000      10194.000000      10194.000000          10194.000000
# mean       0.593222         82.207014         49.697204             68.687816
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10194 non-null  int64
#  1   clonesize             10194 non-null  float64
#  2   honeybee              10194 non-null  float64
#  3   bumbles               10194 non-null  float64
#  4   andrena               10194 non-null  float64
#  5   osmia                 10194 non-null  float64
#  6   MaxOfUpperTRange      10194 non-null  float64
#  7   MinOfUpperTRange      10194 non-null  float64
#  8   AverageOfUpperTRange  10194 non-null  float64
#  9   MaxOfLowerTRange      10194 non-null  float64
#  10  MinOfLowerTRange      10194 non-null  float64
#  11  AverageOfLowerTRange  10194 non-null  float64
#  12  RainingDays           10194 non-null  float64
#  13  AverageRainingDays    10194 non-null  float64
# ...

# %%
test.isnull().sum()
# Out:
# id                      0
# clonesize               0
# honeybee                0
# bumbles                 0
# andrena                 0
# osmia                   0
# MaxOfUpperTRange        0
# MinOfUpperTRange        0
# AverageOfUpperTRange    0
# MaxOfLowerTRange        0
# MinOfLowerTRange        0
# AverageOfLowerTRange    0
# RainingDays             0
# AverageRainingDays      0
# fruitset                0
# fruitmass               0
# seeds                   0
# dtype: int64

# %%
train1=train.drop('id',axis=1)
train1.head(5)
# Out:
#    clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0       25.0      0.50     0.25     0.75   0.50              69.7
# 1       25.0      0.50     0.25     0.50   0.50              69.7
# 2       12.5      0.25     0.25     0.63   0.63              86.0
# 3       12.5      0.25     0.25     0.63   0.50              77.4
# 4       25.0      0.50     0.25     0.63   0.63              77.4
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              42.1                  58.2              50.2              24.3
# 1              42.1                  58.2              50.2              24.3
# 2              52.0                  71.9              62.0              30.0
# 3              46.8                  64.7              55.8              27.0
# 4              46.8                  64.7              55.8              27.0
#
#    AverageOfLowerTRange  RainingDays  AverageRainingDays  fruitset  fruitmass  \
# ...

# %%
test1=test.drop('id',axis=1)
test1.head(5)
# Out:
#    clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0       25.0      0.25     0.25     0.25   0.25              86.0
# 1       12.5      0.25     0.25     0.75   0.63              94.6
# 2       12.5      0.25     0.25     0.63   0.63              86.0
# 3       25.0      0.50     0.38     0.38   0.63              86.0
# 4       37.5      0.75     0.25     0.25   0.25              94.6
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              57.2                  79.0              68.2              33.0
# 2              52.0                  71.9              62.0              30.0
# 3              52.0                  71.9              62.0              30.0
# 4              57.2                  79.0              68.2              33.0
#
#    AverageOfLowerTRange  RainingDays  AverageRainingDays  fruitset  fruitmass  \
# ...

# %%
cols=train1.columns
cols
# Out:
# Index(['clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'MaxOfUpperTRange', 'MinOfUpperTRange', 'AverageOfUpperTRange',
#        'MaxOfLowerTRange', 'MinOfLowerTRange', 'AverageOfLowerTRange',
#        'RainingDays', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds',
#        'yield'],
#       dtype='object')

# %%
fig, axes = plt.subplots( nrows = len(cols) , ncols = 3, figsize =(20, 80))
axes = axes.flatten()
idx = 0
for col in cols:
  sns.kdeplot(train1[col], label='train', ax=axes[idx], fill=False)
  sns.histplot(train1[col], label='train', ax=axes[idx + 1], stat="density")
  if col != 'yield':
        sns.kdeplot(test1[col], label='test', ax=axes[idx], fill=False)
        sns.histplot(test1[col], label='test', ax=axes[idx + 1], stat="density")
  sns.scatterplot(x=col, y="yield", label='train', ax=axes[idx + 2], data=train1)
  axes[idx].legend()
  axes[idx+1].legend()
  axes[idx+2].legend()
  idx+=3

# %% [markdown]
# **Inferences from above work:**
#
#
#
# 1. There are no null values in any columns in both train and test dataset
# 1.   A few kernel density estimation plots like andrena and honeybee and osmia are right skewed or left skewed

# %%
plt.figure(figsize=(15,20))
sns.heatmap(train1.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,20))
sns.heatmap(test1.corr(),annot=True,cmap='plasma')
# Out:
# <Axes: >

# %% [markdown]
# **From the Above heatmaps we can see that  the followings columns have correlation high (>0.94 or lie in redder or yellow region in train and test heatmap)**
#
# *  'MinOfUpperTRange',
# * 'AverageOfUpperTRange',
# *  'MaxOfLowerTRange',
# *  'MinOfLowerTRange',
# *  'AverageOfLowerTRange',
# *  'AverageRainingDays

# %%
col=['MinOfUpperTRange',
'AverageOfUpperTRange',
'MaxOfLowerTRange',
'MinOfLowerTRange',
'AverageOfLowerTRange',
'AverageRainingDays']
train1.drop(col,axis=1,inplace=True)
test1.drop(col,axis=1,inplace=True)

# %%
train1.columns
# Out:
# Index(['clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'MaxOfUpperTRange', 'RainingDays', 'fruitset', 'fruitmass', 'seeds',
#        'yield'],
#       dtype='object')

# %%
test1.columns
# Out:
# Index(['clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'MaxOfUpperTRange', 'RainingDays', 'fruitset', 'fruitmass', 'seeds'],
#       dtype='object')

# %%
X=train1.drop('yield',axis=1)
Y=train1['yield']

# %%
from sklearn.preprocessing import StandardScaler

# %%
se=StandardScaler()
X_standard=se.fit_transform(X)
test_standard=se.transform(test1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
me=MinMaxScaler()
X_scaled=me.fit_transform(X)
test_scaled=me.transform(test1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()
model.fit(X_standard,Y)
# Out:
# RandomForestRegressor()

# %%
Y_predict_standard=model.predict(test_standard)
Y_predict_standard
# Out:
# array([4296.6290087, 6334.4649596, 7083.6697171, ..., 6420.0739998,
#        4443.0925528, 7113.5765724])

# %%
submission=pd.DataFrame()
submission['yield']=Y_predict_standard
submission.index+=15289

# %%
submission.head(10)
# Out:
#              yield
# 15289  4296.629009
# 15290  6334.464960
# 15291  7083.669717
# 15292  4493.998554
# 15293  4298.691484
# 15294  5114.362513
# 15295  7406.191648
# 15296  6355.193819
# 15297  7954.793539
# 15298  4300.673621

# %%
submission.to_csv("submission.csv",index=True,index_label="id",header=True)

# %%
# !kaggle competitions submit -c playground-series-s3e14 -f submission.csv -m "submission 2"
# Out:
# 100% 233k/233k [00:03<00:00, 78.7kB/s]
# Successfully submitted to Prediction of Wild Blueberry Yield
